# %%
import pandas as pd
import ast
import numpy as np
import time

# %%
from load import merge

# %%
UTRL_RAW = 'https://minio.lab.sspcloud.fr/nguibe/mise-en-prod/recipes.parquet'
recipes = pd.read_parquet(URL_RAW)

# %%
recipes
# Out:
#         RecipeId                                              Name  \
# 0           38.0                 Low-Fat Berry Blue Frozen Dessert
# 1           39.0                                           Biryani
# 2           40.0                                     Best Lemonade
# 3           41.0                    Carina's Tofu-Vegetable Kebabs
# 4           42.0                                      Cabbage Soup
# ...          ...                                               ...
# 522512  541379.0                    Meg's Fresh Ginger Gingerbread
# 522513  541380.0  Roast Prime Rib au Poivre with Mixed Peppercorns
# 522514  541381.0                             Kirshwasser Ice Cream
# 522515  541382.0          Quick & Easy Asian Cucumber Salmon Rolls
# 522516  541383.0                           Spicy Baked Scotch Eggs
#
#           AuthorId      AuthorName CookTime PrepTime TotalTime  \
# 0             1533          Dancer    PT24H    PT45M  PT24H45M
# ...

# %%
merged = merge('https://minio.lab.sspcloud.fr/nguibe/mise-en-prod/recipes.parquet', 'https://minio.lab.sspcloud.fr/nguibe/mise-en-prod/recipes_data.parquet')
# Out:
# Nutrition data set loaded in --- 43.88794445991516 seconds ---
# Cleaned in --- 8.349717378616333 seconds ---
# Measurements data set loaded in --- 328.09935998916626 seconds ---
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
merged.head()
# Out:
#                                      Name          AuthorName CookTime  \
# 0                          Buttermilk Pie            thefensk     PT1H
# 1  Low-Fat Burgundy Beef & Vegetable Stew              Dancer  PT2H14M
# 2                  Cheeseburger Casserole  Marg CaymanDesigns    PT25M
# 3       Appetizers-Easy Stuffed Mushrooms             ann joy     PT7M
# 4                Chocolate Zucchini Bread           itsjustme     PT1H
#
#   PrepTime TotalTime                                        Description  \
# 0    PT20M   PT1H20M  This recipe was originally noted by my wife on...
# 1    PT30M   PT2H44M  Make and share this Low-Fat Burgundy Beef & Ve...
# 2    PT15M     PT40M  This is popular with the kids especially. My h...
# 3    PT35M     PT42M  Hi,  Here is a great recipe for Stuffed Mushro...
# 4    PT25M   PT1H25M  Make and share this Chocolate Zucchini Bread r...
#
#                                               Images RecipeCategory  \
# ...

# %%
len(merged)
# Out:
# 10648

# %%
merged
# Out:
#                                          Name          AuthorName CookTime  \
# 0                              Buttermilk Pie            thefensk     PT1H
# 1      Low-Fat Burgundy Beef & Vegetable Stew              Dancer  PT2H14M
# 2                      Cheeseburger Casserole  Marg CaymanDesigns    PT25M
# 3           Appetizers-Easy Stuffed Mushrooms             ann joy     PT7M
# 4                    Chocolate Zucchini Bread           itsjustme     PT1H
# ...                                       ...                 ...      ...
# 10643           Cheesy Buffalo Chicken Skulls   Jonathan Melendez    PT30M
# 10644                   Batty Ube Cream Puffs      luxeandthelady    PT12M
# 10645          Rapid Rise Skillet Yeast Rolls          Bonnie G 2    PT25M
# 10646             Spaghetti Squash Tater Tots       Arlyn Osborne    PT12M
# 10647    Boulets Liegeois (Belgian Meatballs)         Chef PotPie  PT1H30M
#
# ...

# %% [markdown]
# # na handling

# %%
start_time = time.time()
keep = [i for i in df.columns if i not in drop]
df_na = pd.read_parquet('recipes.parquet', columns=keep)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 40.80111789703369 seconds ---

# %%
df_na.isna().sum()
# Out:
# Name                               0
# AuthorName                         0
# CookTime                       82545
# PrepTime                           0
# TotalTime                          0
# Description                        5
# Images                             1
# RecipeCategory                   751
# Keywords                           0
# RecipeIngredientQuantities         0
# RecipeIngredientParts              0
# AggregatedRating              253223
# ReviewCount                   247489
# Calories                           0
# FatContent                         0
# SaturatedFatContent                0
# CholesterolContent                 0
# SodiumContent                      0
# CarbohydrateContent                0
# FiberContent                       0
# SugarContent                       0
# ProteinContent                     0
# RecipeServings                182911
# RecipeInstructions                 0
# dtype: int64

# %%
df_na.dtypes
# Out:
# Name                           object
# AuthorName                     object
# CookTime                       object
# PrepTime                       object
# TotalTime                      object
# Description                    object
# Images                         object
# RecipeCategory                 object
# Keywords                       object
# RecipeIngredientQuantities     object
# RecipeIngredientParts          object
# AggregatedRating              float64
# ReviewCount                   float64
# Calories                      float64
# FatContent                    float64
# SaturatedFatContent           float64
# CholesterolContent            float64
# SodiumContent                 float64
# CarbohydrateContent           float64
# FiberContent                  float64
# SugarContent                  float64
# ProteinContent                float64
# RecipeServings                float64
# RecipeInstructions             object
# dtype: object

# %%
numeric_float_var = ['AggregatedRating', 'Calories','FatContent','SaturatedFatContent','CholesterolContent'
               ,'SodiumContent','CarbohydrateContent','FiberContent','SugarContent','ProteinContent']
numeric_int_var= ['ReviewCount','RecipeServings']
string_var= ['Name','AuthorName','CookTime','PrepTime','TotalTime','Description','RecipeCategory']
list_var = ['Images','Keywords','RecipeInstructions']

# %%
df_na[numeric_float_var] = df_na[numeric_float_var].astype(float)
df_na[numeric_int_var] = df_na[numeric_int_var].astype(int)
df_na[string_var] = df_na[string_var].astype(str)
df_na[list_var] = df_na[string_var].astype(list)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[36], line 2
#       1 df_na[numeric_float_var] = df_na[numeric_float_var].astype(float)
# ----> 2 df_na[numeric_int_var] = df_na[numeric_int_var].astype(int)
#       3 df_na[string_var] = df_na[string_var].astype(str)
#       4 df_na[list_var] = df_na[string_var].astype(list)
#
# File c:\Users\guibe\anaconda3\envs\vscode\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# ...
