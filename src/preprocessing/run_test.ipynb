# %%
import pandas as pd

# %% [markdown]
# # test en local

# %%
from load import merge

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\marie\\OneDrive\\Documents\\cours\\ensae\\3A\\Mise en prod\\Projet-Mise-en-prod-3A\\src\\preprocessing'

# %%
path1 = '../../../recipes.parquet'
path2 = '../../../recipes_data.parquet'

merged = merge(path1, path2)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 4
#       1 path1 = '../../../recipes.parquet'
#       2 path2 = '../../../recipes_data.parquet'
# ----> 4 merged = merge(path1, path2)
#
# File c:\Users\marie\OneDrive\Documents\cours\ensae\3A\Mise en prod\Projet-Mise-en-prod-3A\src\preprocessing\load.py:138, in merge(nutrition_data_path, measurements_data_path)
#     120 def merge(nutrition_data_path:str, measurements_data_path:str) -> pd.DataFrame:
#     121     """
#     122     This function merges two datasets based on recipe names and the first instruction in each dataset.
#     123
#    (...)    136     pd.DataFrame: The merged DataFrame.
#     137     """
# --> 138     df_nutrition, recipe_merge = load_nutrition_data(nutrition_data_path)
#     139     df_measurements = load_measurements_data(measurements_data_path, recipe_merge)
#     140     # create col to merge
#
# File c:\Users\marie\OneDrive\Documents\cours\ensae\3A\Mise en prod\Projet-Mise-en-prod-3A\src\preprocessing\load.py:66, in load_nutrition_data(nutrition_data_path)
#      64 # load first data set
#      65 start_time = time.time()
# ---> 66 df = pd.read_parquet(nutrition_data_path, columns=keep_col_nutrition)
#      67 end_time = time.time()
#      68 print("Nutrition data set loaded in --- %s seconds ---" % (end_time - start_time))
#
# File c:\Users\marie\OneDrive\Documents\cours\ensae\3A\Mise en prod\.uv_mep\Lib\site-packages\pandas\io\parquet.py:667, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     664     use_nullable_dtypes = False
#     665 check_dtype_backend(dtype_backend)
# --> 667 return impl.read(
#     668     path,
#     669     columns=columns,
#     670     filters=filters,
#     671     storage_options=storage_options,
#     672     use_nullable_dtypes=use_nullable_dtypes,
#     673     dtype_backend=dtype_backend,
#     674     filesystem=filesystem,
#     675     **kwargs,
#     676 )
#
# File c:\Users\marie\OneDrive\Documents\cours\ensae\3A\Mise en prod\.uv_mep\Lib\site-packages\pandas\io\parquet.py:267, in PyArrowImpl.read(self, path, columns, filters, use_nullable_dtypes, dtype_backend, storage_options, filesystem, **kwargs)
#     264 if manager == "array":
#     265     to_pandas_kwargs["split_blocks"] = True  # type: ignore[assignment]
# --> 267 path_or_handle, handles, filesystem = _get_path_or_handle(
#     268     path,
#     269     filesystem,
#     270     storage_options=storage_options,
#     271     mode="rb",
#     272 )
#     273 try:
#     274     pa_table = self.api.parquet.read_table(
#     275         path_or_handle,
#     276         columns=columns,
#    (...)    279         **kwargs,
#     280     )
#
# File c:\Users\marie\OneDrive\Documents\cours\ensae\3A\Mise en prod\.uv_mep\Lib\site-packages\pandas\io\parquet.py:140, in _get_path_or_handle(path, fs, storage_options, mode, is_dir)
#     130 handles = None
#     131 if (
#     132     not fs
#     133     and not is_dir
#    (...)    138     # fsspec resources can also point to directories
#     139     # this branch is used for example when reading from non-fsspec URLs
# --> 140     handles = get_handle(
#     141         path_or_handle, mode, is_text=False, storage_options=storage_options
#     142     )
#     143     fs = None
#     144     path_or_handle = handles.handle
#
# File c:\Users\marie\OneDrive\Documents\cours\ensae\3A\Mise en prod\.uv_mep\Lib\site-packages\pandas\io\common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)    878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../../recipes.parquet'

# %%
from format import data_preprocessing

# %%
df_prepro = data_preprocessing(merged)

# %%
from filter import data_filter

# %%
df_filtered = data_filter(df_prepro)

# %%
#df_filtered.to_parquet('app_dataset.parquet')

# %% [markdown]
# # test appel données s3
#
# (dépend de la connexion internet)

# %%
path1 = 'https://minio.lab.sspcloud.fr/nguibe/mise-en-prod/recipes.parquet'
path2 = 'https://minio.lab.sspcloud.fr/nguibe/mise-en-prod/recipes_data.parquet'
merged = merge(path1, path2)
# Out:
# Nutrition data set loaded in --- 21.51467537879944 seconds ---
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 path1 = 'https://minio.lab.sspcloud.fr/nguibe/mise-en-prod/recipes.parquet'
#       2 path2 = 'https://minio.lab.sspcloud.fr/nguibe/mise-en-prod/recipes_data.parquet'
# ----> 3 merged = merge(path1, path2)
#
# File c:\Users\marie\OneDrive\Documents\cours\ensae\3A\Mise en prod\Projet-Mise-en-prod-3A\src\preprocessing\load.py:138, in merge(nutrition_data_path, measurements_data_path)
#     120 def merge(nutrition_data_path:str, measurements_data_path:str) -> pd.DataFrame:
#     121     """
#     122     This function merges two datasets based on recipe names and the first instruction in each dataset.
#     123
#    (...)    136     pd.DataFrame: The merged DataFrame.
#     137     """
# --> 138     df_nutrition, recipe_merge = load_nutrition_data(nutrition_data_path)
#     139     df_measurements = load_measurements_data(measurements_data_path, recipe_merge)
#     140     # create col to merge
#
# File c:\Users\marie\OneDrive\Documents\cours\ensae\3A\Mise en prod\Projet-Mise-en-prod-3A\src\preprocessing\load.py:80, in load_nutrition_data(nutrition_data_path)
#      78 string_var= ['Name','AuthorName','CookTime','PrepTime','TotalTime','Description','RecipeCategory']
#      79 list_var = ['Images','Keywords','RecipeInstructions']
# ---> 80 df = handle_na(df, numeric_float_var, numeric_int_var, string_var, list_var)
#      81 print("Cleaned in --- %s seconds ---" % (time.time() - end_time))
#      82 recipe_name = df['Name'].drop_duplicates().to_list()
#
# File c:\Users\marie\OneDrive\Documents\cours\ensae\3A\Mise en prod\Projet-Mise-en-prod-3A\src\preprocessing\format.py:49, in handle_na(df, numeric_float_var, numeric_int_var, string_var, list_var)
#      35 def handle_na(df : pd.DataFrame,numeric_float_var : List[str] = [], numeric_int_var : List[str] = [], string_var: List[str] = [], list_var: List[str] = []) -> pd.DataFrame:
#      36     """
#      37     This function handles missing values in the DataFrame by performing type conversions and removing rows with missing data.
#      38
#    (...)     47     pd.DataFrame: The DataFrame with missing values handled and type conversions applied.
#      48     """
# ---> 49     df = handle_type(df, numeric_float_var, numeric_int_var, string_var)
#      50     # we remove na values
#      51     len_before = len(df)
#
# TypeError: handle_type() takes from 1 to 3 positional arguments but 4 were given

# %%
df_prepro = data_preprocessing(merged)
df_filtered = data_filter(df_prepro)

# %% [markdown]
# # final data set

# %%
app = pd.read_parquet('app_dataset.parquet')

# %%
app
# Out:
#                                                Name   AuthorName CookTime  \
# 0                 Low-Fat Berry Blue Frozen Dessert       Dancer     24 h
# 1                                           Biryani     elly9812   25 min
# 2                                      Cabbage Soup    Duckie067   30 min
# 3                                      Cabbage Soup    Duckie067   30 min
# 4        Buttermilk Pie With Gingersnap Crumb Crust    tristitia   50 min
# ...                                             ...          ...      ...
# 47467                           Cuban Mojo Potatoes       PanNan   45 min
# 47468                          Mojo Pork Tenderloin       PanNan   40 min
# 47469  Slow Cooker Ropa Vieja (Cuban Shredded Beef)       PanNan      8 h
# 47470                 Dutch Butter Cake (Boterkoek)  Chef PotPie   30 min
# 47471   Dutch Fried Potatoes (Gebakken Aardappelen)  Chef PotPie   30 min
#
#       PrepTime    TotalTime  \
# 0       45 min  24 h 45 min
# 1          4 h   4 h 25 min
# 2       20 min       50 min
# 3       20 min       50 min
# 4       30 min   1 h 20 min
# ...        ...          ...
# 47467   15 min          1 h
# 47468   15 min       55 min
# 47469   10 min   8 h 10 min
# 47470   10 min       40 min
# 47471   10 min       40 min
#
#                                              Description  \
# 0      Make and share this Low-Fat Berry Blue Frozen ...
# 1      Make and share this Biryani recipe from Food.com.
# 2      Make and share this Cabbage Soup recipe from F...
# 3      Make and share this Cabbage Soup recipe from F...
# 4      Make and share this Buttermilk Pie With Ginger...
# ...                                                  ...
# 47467  Make and share this Cuban Mojo Potatoes recipe...
# 47468  Delicious and easy.  When planning, please all...
# 47469  Make and share this Slow Cooker Ropa Vieja (Cu...
# 47470  A traditional Dutch cake, similar to shortbrea...
# 47471  Delicious side dish made from leftover boiled ...
#
#                                                   Images   RecipeCategory  \
# 0      https://img.sndimg.com/food/image/upload/w_555...  Frozen Desserts
# 1      https://img.sndimg.com/food/image/upload/w_555...   Chicken Breast
# 2      https://img.sndimg.com/food/image/upload/w_555...        Vegetable
# 3      https://img.sndimg.com/food/image/upload/w_555...        Vegetable
# 4      https://img.sndimg.com/food/image/upload/w_555...              Pie
# ...                                                  ...              ...
# 47467  https://img.sndimg.com/food/image/upload/w_555...            Cuban
# 47468  https://img.sndimg.com/food/image/upload/w_555...            Cuban
# 47469  https://img.sndimg.com/food/image/upload/v1/im...            Cuban
# 47470  https://img.sndimg.com/food/image/upload/w_555...          Dessert
# 47471  https://img.sndimg.com/food/image/upload/w_555...            Dutch
#
#                                                 Keywords  \
# 0      [#Dessert, #Low Protein, #Low Cholesterol, #He...
# 1      [#Chicken Thigh & Leg, #Chicken, #Poultry, #Me...
# 2      [#Low Protein, #Vegan, #Low Cholesterol, #Heal...
# 3      [#Low Protein, #Vegan, #Low Cholesterol, #Heal...
# 4      [#Dessert, #Healthy, #Weeknight, #Oven, #< 4 H...
# ...                                                  ...
# 47467  [#Caribbean, #Low Protein, #Low Cholesterol, #...
# 47468                           [#Caribbean, #< 60 Mins]
# 47469                                       [#Caribbean]
# 47470                    [#Dutch, #European, #< 60 Mins]
# 47471  [#European, #Low Protein, #Low Cholesterol, #H...
#
#                               RecipeIngredientQuantities  ...  \
# 0                                         [4, 1⁄4, 1, 1]  ...
# 1      [1, 4, 2, 2, 8, 1⁄4, 8, 1⁄2, 1, 1, 1⁄4, 1⁄4, 1...  ...
# 2                                       [46, 4, 1, 2, 1]  ...
# 3                                       [46, 4, 1, 2, 1]  ...
# 4                 [3⁄4, 1, 1, 2, 3, 1⁄4, 1, 1⁄2, 1⁄2, 2]  ...
# ...                                                  ...  ...
# 47467              [1 1⁄2, 1, 1⁄2, 1⁄4, 1, 6, 3, 1, 1⁄2]  ...
# 47468         [8, 2, 1, 1, 1, 1⁄2, 1⁄2, 1⁄2, 1⁄4, 1 1⁄2]  ...
# 47469      [3, 1, 1, 1, 1, 6, 1⁄2, 1, 28, 6, 1, 1, 1, 1]  ...
# 47470                    [2⁄3, 1, 1, 1, 1 1⁄2, 1⁄4, 1⁄2]  ...
# 47471                                       [6, 2, 1, 4]  ...
#
#                                                     link  \
# 0      www.food.com/recipe/low-fat-berry-blue-frozen-...
# 1                         www.food.com/recipe/biryani-39
# 2                    www.food.com/recipe/cabbage-soup-42
# 3                www.food.com/recipe/cabbage-soup-204921
# 4      www.food.com/recipe/buttermilk-pie-with-ginger...
# ...                                                  ...
# 47467     www.food.com/recipe/cuban-mojo-potatoes-539090
# 47468    www.food.com/recipe/mojo-pork-tenderloin-539091
# 47469  www.food.com/recipe/slow-cooker-ropa-vieja-cub...
# 47470  www.food.com/recipe/dutch-butter-cake-boterkoe...
# 47471  www.food.com/recipe/dutch-fried-potatoes-gebak...
#
#                                                      NER  CookTime_minutes  \
# 0        [blueberry, sugar, vanilla yogurt, lemon juice]              1440
# 1      [tomato, basmati rice, coriander seed, egg, ma...                25
# 2         [cabbage, onion, celery, carrot, tomato juice]                30
# 3      [cabbage, tomato paste, pepper, onion, mushroo...                30
# 4      [buttermilk, gingersnap crumb, egg, sugar, gra...                50
# ...                                                  ...               ...
# 47467  [gold potato, scallion, cilantro, red pepper, ...                45
# 47468  [ground cumin, cilantro, orange, ground black ...                40
# 47469  [flank, cumin, oregano, sugar, green bell pepp...               480
# 47470  [egg, sugar, baking powder, salt, almond flavo...                30
# 47471                     [potato, bacon, onion, butter]                30
#
#        PrepTime_minutes  TotalTime_minutes  TotalTime_cat   RecipeType  \
# 0                    45               1485           > 1h      Dessert
# 1                   240                265           > 1h  Main Course
# 2                    20                 50           < 1h  Main Course
# 3                    20                 50           < 1h  Main Course
# 4                    30                 80           > 1h      Dessert
# ...                 ...                ...            ...          ...
# 47467                15                 60           < 1h  Main Course
# 47468                15                 55           < 1h  Main Course
# 47469                10                490           > 1h  Main Course
# 47470                10                 40           < 1h      Dessert
# 47471                10                 40           < 1h  Main Course
#
#        Beginner_Friendly  Vegetarian_Friendly  World_Cuisine
# 0                  False                 True        Unknown
# 1                  False                False        Unknown
# 2                  False                 True        Unknown
# 3                  False                False        Unknown
# 4                  False                False        Unknown
# ...                  ...                  ...            ...
# 47467              False                 True        Unknown
# 47468              False                False        Unknown
# 47469              False                False        Unknown
# 47470              False                 True        Unknown
# 47471              False                False        Unknown
#
# [47472 rows x 38 columns]

# %%
app['World_Cuisine'].value_counts()
# Out:
# World_Cuisine
# Unknown    47472
# Name: count, dtype: int64

# %%
app.columns
# Out:
# Index(['Name', 'AuthorName', 'CookTime', 'PrepTime', 'TotalTime',
#        'Description', 'Images', 'RecipeCategory', 'Keywords',
#        'RecipeIngredientQuantities', 'RecipeIngredientParts',
#        'AggregatedRating', 'ReviewCount', 'Calories', 'FatContent',
#        'SaturatedFatContent', 'CholesterolContent', 'SodiumContent',
#        'CarbohydrateContent', 'FiberContent', 'SugarContent', 'ProteinContent',
#        'RecipeServings', 'RecipeInstructions', 'to_merge', 'title',
#        'directions', 'ingredients', 'link', 'NER', 'CookTime_minutes',
#        'PrepTime_minutes', 'TotalTime_minutes', 'TotalTime_cat', 'RecipeType',
#        'Beginner_Friendly', 'Vegetarian_Friendly', 'World_Cuisine'],
#       dtype='object')

# %%
import sweetviz as sv
import pandas as pd

# Generate the Sweetviz report
report = sv.analyze(app[['Name','CookTime', 'PrepTime', 'TotalTime','RecipeCategory','AggregatedRating', 'ReviewCount', 'Calories', 'FatContent',
       'SaturatedFatContent', 'CholesterolContent', 'SodiumContent',
       'CarbohydrateContent', 'FiberContent', 'SugarContent', 'ProteinContent',
       'RecipeServings','CookTime_minutes',
       'PrepTime_minutes', 'TotalTime_minutes', 'TotalTime_cat', 'RecipeType',
       'Beginner_Friendly', 'Vegetarian_Friendly', 'World_Cuisine']])

# Display the report in Jupyter notebook
report.show_html('sweetviz_report.html')
# Out:
# Done! Use 'show' commands to display/save.   |██████████| [100%]   00:01 -> (00:00 left)
# Report sweetviz_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
print(app.dtypes)
# Out:
# Name                           object
# AuthorName                     object
# CookTime                       object
# PrepTime                       object
# TotalTime                      object
# Description                    object
# Images                         object
# RecipeCategory                 object
# Keywords                       object
# RecipeIngredientQuantities     object
# RecipeIngredientParts          object
# AggregatedRating              float64
# ReviewCount                     Int64
# Calories                      float64
# FatContent                    float64
# SaturatedFatContent           float64
# CholesterolContent            float64
# SodiumContent                 float64
# CarbohydrateContent           float64
# FiberContent                  float64
# SugarContent                  float64
# ProteinContent                float64
# RecipeServings                  Int64
# RecipeInstructions             object
# to_merge                       object
# title                          object
# directions                     object
# ingredients                    object
# link                           object
# NER                            object
# CookTime_minutes                int64
# PrepTime_minutes                int64
# TotalTime_minutes               int64
# TotalTime_cat                  object
# RecipeType                     object
# Beginner_Friendly                bool
# Vegetarian_Friendly              bool
# World_Cuisine                  object
# dtype: object
