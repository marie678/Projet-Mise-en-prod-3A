# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import re
import ast

# %% [markdown]
# ### Import first dataset

# %%
df_recipes2 = pd.read_parquet('/Users/bianp/Desktop/3A DSSA/Recipe_Finder/recipes.parquet')
df_recipes2.head()
# Out:
#    RecipeId                               Name  AuthorId      AuthorName  \
# 0      38.0  Low-Fat Berry Blue Frozen Dessert      1533          Dancer
# 1      39.0                            Biryani      1567        elly9812
# 2      40.0                      Best Lemonade      1566  Stephen Little
# 3      41.0     Carina's Tofu-Vegetable Kebabs      1586         Cyclopz
# 4      42.0                       Cabbage Soup      1538       Duckie067
#
#   CookTime PrepTime TotalTime             DatePublished  \
# 0    PT24H    PT45M  PT24H45M 1999-08-09 21:46:00+00:00
# 1    PT25M     PT4H   PT4H25M 1999-08-29 13:12:00+00:00
# 2     PT5M    PT30M     PT35M 1999-09-05 19:52:00+00:00
# 3    PT20M    PT24H  PT24H20M 1999-09-03 14:54:00+00:00
# 4    PT30M    PT20M     PT50M 1999-09-19 06:19:00+00:00
#
#                                          Description  \
# 0  Make and share this Low-Fat Berry Blue Frozen ...
# 1  Make and share this Biryani recipe from Food.com.
# 2  This is from one of my  first Good House Keepi...
# 3  This dish is best prepared a day in advance to...
# 4  Make and share this Cabbage Soup recipe from F...
#
#                                               Images  ... SaturatedFatContent  \
# 0  [https://img.sndimg.com/food/image/upload/w_55...  ...                 1.3
# 1  [https://img.sndimg.com/food/image/upload/w_55...  ...                16.6
# 2  [https://img.sndimg.com/food/image/upload/w_55...  ...                 0.0
# 3  [https://img.sndimg.com/food/image/upload/w_55...  ...                 3.8
# 4  [https://img.sndimg.com/food/image/upload/w_55...  ...                 0.1
#
#   CholesterolContent SodiumContent CarbohydrateContent  FiberContent  \
# 0                8.0          29.8                37.1           3.6
# 1              372.8         368.4                84.4           9.0
# 2                0.0           1.8                81.5           0.4
# 3                0.0        1558.6                64.2          17.3
# 4                0.0         959.3                25.1           4.8
#
#    SugarContent  ProteinContent  RecipeServings  RecipeYield  \
# 0          30.2             3.2             4.0         None
# 1          20.4            63.4             6.0         None
# 2          77.2             0.3             4.0         None
# 3          32.1            29.3             2.0     4 kebabs
# 4          17.7             4.3             4.0         None
#
#                                   RecipeInstructions
# 0  [Toss 2 cups berries with sugar., Let stand fo...
# 1  [Soak saffron in warm milk for 5 minutes and p...
# 2  [Into a 1 quart Jar with tight fitting lid, pu...
# 3  [Drain the tofu, carefully squeezing out exces...
# 4  [Mix everything together and bring to a boil.,...
#
# [5 rows x 28 columns]

# %%
# Extract relevant columns
selected_columns = ['Name', 
                    'AuthorName', 
                    'CookTime', 
                    'PrepTime', 
                    'TotalTime', 
                    'Description', 
                    'Images', 
                    'RecipeCategory', 
                    'Keywords', 
                    'RecipeIngredientQuantities', 
                    'RecipeIngredientParts', 
                    'AggregatedRating', 
                    'Calories', 
                    'FatContent', 
                    'SugarContent',
                    'ProteinContent', 
                    'RecipeServings', 
                    'RecipeInstructions']
df_recipes2 = df_recipes2[selected_columns]

# %%
# Drop duplicate recipes
df_recipes2 = df_recipes2.drop_duplicates(subset=['Name','AuthorName'])

# %%
df_recipes2.describe()
# Out:
#        AggregatedRating       Calories     FatContent  SugarContent  \
# count     268902.000000  520468.000000  520468.000000  520468.00000
# mean           4.632061     484.473628      24.616125      21.87149
# std            0.641841    1399.174903     111.674705     142.84146
# min            1.000000       0.000000       0.000000       0.00000
# 25%            4.500000     174.200000       5.600000       2.50000
# 50%            5.000000     317.100000      13.800000       6.40000
# 75%            5.000000     529.100000      27.400000      17.90000
# max            5.000000  612854.600000   64368.100000   90682.30000
#
#        ProteinContent  RecipeServings
# count   520468.000000   338261.000000
# mean        17.474475        8.607093
# std         40.186924      114.545381
# min          0.000000        1.000000
# 25%          3.500000        4.000000
# 50%          9.100000        6.000000
# 75%         25.100000        8.000000
# max      18396.200000    32767.000000

# %%
# Filter out outliers
df_recipes2 = df_recipes2[ ( df_recipes2['Calories'] > 0 ) & ( df_recipes2['Calories'] <= 1500) & ( df_recipes2['RecipeServings'] <= 72 ) ]

# %%
# Convert columns of arrays into lists
array_cols = ['Images', 'Keywords', 'RecipeInstructions']
for col in array_cols:
    df_recipes2[col] = df_recipes2[col].apply(
        lambda x: list(x) if isinstance(x, (list, np.ndarray)) and not all(item is None for item in x) else np.nan
    )

# %%
# Keep the first link only in the column 'Images'
df_recipes2['Images'] = df_recipes2['Images'].apply(
    lambda x: x[0] if isinstance(x, list) and len(x) > 0 else np.nan
)

# %%
df_recipes2['RecipeInstructions'] = df_recipes2['RecipeInstructions'].apply(
    lambda x: [instr.strip() + '.' for instr in ' '.join(x).split('.') if instr.strip()] if isinstance(x, list) else np.nan
)

# %%
df_recipes2.isna().sum()
# Out:
# Name                               0
# AuthorName                         0
# CookTime                       50197
# PrepTime                           0
# TotalTime                          0
# Description                        3
# Images                        224357
# RecipeCategory                   459
# Keywords                       11310
# RecipeIngredientQuantities         0
# RecipeIngredientParts              0
# AggregatedRating              162017
# Calories                           0
# FatContent                         0
# SugarContent                       0
# ProteinContent                     0
# RecipeServings                     0
# RecipeInstructions                 0
# dtype: int64

# %%
# Fill NaN values in the column CookTime
df_recipes2['CookTime'] = df_recipes2['CookTime'].fillna('PT0M')

# %%
df_recipes2 = df_recipes2.dropna().reset_index(drop=True)

# %%
df_recipes2
# Out:
#                                     Name      AuthorName CookTime PrepTime  \
# 0      Low-Fat Berry Blue Frozen Dessert          Dancer    PT24H    PT45M
# 1                                Biryani        elly9812    PT25M     PT4H
# 2                          Best Lemonade  Stephen Little     PT5M    PT30M
# 3         Carina's Tofu-Vegetable Kebabs         Cyclopz    PT20M    PT24H
# 4                           Cabbage Soup       Duckie067    PT30M    PT20M
# ...                                  ...             ...      ...      ...
# 86990         Suffering Bastard Cocktail     Chef PotPie     PT0M     PT5M
# 86991               Cantaloupe Margarita     Chef PotPie     PT0M    PT10M
# 86992              Honey Paloma Cocktail     Chef PotPie     PT0M    PT20M
# 86993       Backyard Breakfast Egg Salad         duonyte     PT0M    PT20M
# 86994                   Homemade Ketchup    YummyFood510     PT0M     PT5M
#
#       TotalTime                                        Description  \
# 0      PT24H45M  Make and share this Low-Fat Berry Blue Frozen ...
# 1       PT4H25M  Make and share this Biryani recipe from Food.com.
# 2         PT35M  This is from one of my  first Good House Keepi...
# 3      PT24H20M  This dish is best prepared a day in advance to...
# 4         PT50M  Make and share this Cabbage Soup recipe from F...
# ...         ...                                                ...
# 86990      PT5M  This rum and gin based cocktail was served as ...
# 86991     PT10M  I've been trying all kinds of margaritas this ...
# 86992     PT20M  Added this to the list of cocktails to try thi...
# 86993     PT20M  I was gifted with eggs from the backyard coop ...
# 86994      PT5M  Homemade ketchup is so easy and is made with j...
#
#                                                   Images   RecipeCategory  \
# 0      https://img.sndimg.com/food/image/upload/w_555...  Frozen Desserts
# 1      https://img.sndimg.com/food/image/upload/w_555...   Chicken Breast
# 2      https://img.sndimg.com/food/image/upload/w_555...        Beverages
# 3      https://img.sndimg.com/food/image/upload/w_555...         Soy/Tofu
# 4      https://img.sndimg.com/food/image/upload/w_555...        Vegetable
# ...                                                  ...              ...
# 86990  https://img.sndimg.com/food/image/upload/w_555...        Beverages
# 86991  https://img.sndimg.com/food/image/upload/w_555...        Beverages
# 86992  https://img.sndimg.com/food/image/upload/w_555...        Beverages
# 86993  https://img.sndimg.com/food/image/upload/w_555...        Breakfast
# 86994  https://img.sndimg.com/food/image/upload/w_555...        < 15 Mins
#
#                                                 Keywords  \
# 0      [Dessert, Low Protein, Low Cholesterol, Health...
# 1      [Chicken Thigh & Leg, Chicken, Poultry, Meat, ...
# 2      [Low Protein, Low Cholesterol, Healthy, Summer...
# 3      [Beans, Vegetable, Low Cholesterol, Weeknight,...
# 4      [Low Protein, Vegan, Low Cholesterol, Healthy,...
# ...                                                  ...
# 86990                                        [< 15 Mins]
# 86991                                  [< 15 Mins, Easy]
# 86992                                        [< 30 Mins]
# 86993  [Brunch, < 30 Mins, Easy, Inexpensive, From Sc...
# 86994                                             [Easy]
#
#                               RecipeIngredientQuantities  \
# 0                                         [4, 1⁄4, 1, 1]
# 1      [1, 4, 2, 2, 8, 1⁄4, 8, 1⁄2, 1, 1, 1⁄4, 1⁄4, 1...
# 2                     [1 1⁄2, 1, None, 1 1⁄2, None, 3⁄4]
# 3      [12, 1, 2, 1, 10, 1, 3, 2, 2, 2, 1, 2, 1⁄2, 1⁄...
# 4                                       [46, 4, 1, 2, 1]
# ...                                                  ...
# 86990                         [1, 1, 1⁄2, 2, None, None]
# 86991                          [4, 1⁄2, 1⁄4, 2, 1, 2, 2]
# 86992                       [2, 1, 2, 2, 2, 1, 1⁄4, 1⁄4]
# 86993                 [6, 2, 2, 2, 4, 3, 1, 1⁄4, 1⁄4, 4]
# 86994     [1 1⁄2, 3, 1⁄2, 1⁄8, 1⁄3, 1⁄2, 1⁄8, 1⁄8, 1, 4]
#
#                                    RecipeIngredientParts  AggregatedRating  \
# 0      [blueberries, granulated sugar, vanilla yogurt...               4.5
# 1      [saffron, milk, hot green chili peppers, onion...               3.0
# 2      [sugar, lemons, rind of, lemon, zest of, fresh...               4.5
# 3      [extra firm tofu, eggplant, zucchini, mushroom...               4.5
# 4      [plain tomato juice, cabbage, onion, carrots, ...               4.5
# ...                                                  ...               ...
# 86990  [Bourbon, fresh lime juice, ginger ale, mint s...               5.0
# 86991       [cantaloupe, lime juice, sugar, coarse salt]               5.0
# 86992  [grapefruit juice, fresh lime juice, honey syr...               5.0
# 86993  [eggs, mayonnaise, Dijon mustard, red onions, ...               5.0
# 86994  [tomato paste, white sugar, cold water, allspi...               5.0
#
#        Calories  FatContent  SugarContent  ProteinContent  RecipeServings  \
# 0         170.9         2.5          30.2             3.2             4.0
# 1        1110.7        58.8          20.4            63.4             6.0
# 2         311.1         0.2          77.2             0.3             4.0
# 3         536.1        24.0          32.1            29.3             2.0
# 4         103.6         0.4          17.7             4.3             4.0
# ...         ...         ...           ...             ...             ...
# 86990     160.4         0.0           0.3             0.1             1.0
# 86991     165.1         0.6          38.2             2.8             2.0
# 86992     285.4         0.1          75.5             0.6             1.0
# 86993     179.7        10.9           1.0            13.3             4.0
# 86994     160.6         0.7          28.6             5.8             3.0
#
#                                       RecipeInstructions
# 0      [Toss 2 cups berries with sugar., Let stand fo...
# 1      [Soak saffron in warm milk for 5 minutes and p...
# 2      [Into a 1 quart Jar with tight fitting lid, pu...
# 3      [Drain the tofu, carefully squeezing out exces...
# 4      [Mix everything together and bring to a boil.,...
# ...                                                  ...
# 86990  [Add the bourbon, gin, lime juice and bitters ...
# 86991  [In a blender or food processor, blend the can...
# 86992  [For the honey syrup: In a small sauce pot com...
# 86993  [1., Chop the eggs., 2., Combine the mayonnais...
# 86994  [Whisk all ingredients together in a bowl., En...
#
# [86995 rows x 18 columns]

# %% [markdown]
# ### Import second dataset with units of measurement

# %%
df_2M = pd.read_csv('/Users/bianp/Desktop/3A DSSA/Recipe_Finder/recipes_data.csv')
df_2M
# Out:
#                                                  title  \
# 0                                  No-Bake Nut Cookies
# 1                                Jewell Ball'S Chicken
# 2                                          Creamy Corn
# 3                                        Chicken Funny
# 4                                 Reeses Cups(Candy)
# ...                                                ...
# 2231137                            Sunny's Fake Crepes
# 2231138                                     Devil Eggs
# 2231139  Extremely Easy and Quick - Namul Daikon Salad
# 2231140     Pan-Roasted Pork Chops With Apple Fritters
# 2231141                 Polpette in Spicy Tomato Sauce
#
#                                                ingredients  \
# 0        ["1 c. firmly packed brown sugar", "1/2 c. eva...
# 1        ["1 small jar chipped beef, cut up", "4 boned ...
# 2        ["2 (16 oz.) pkg. frozen corn", "1 (8 oz.) pkg...
# 3        ["1 large whole chicken", "2 (10 1/2 oz.) cans...
# 4        ["1 c. peanut butter", "3/4 c. graham cracker ...
# ...                                                    ...
# 2231137  ["1/2 cup chocolate hazelnut spread (recommend...
# 2231138  ["1 dozen eggs", "1 paprika", "1 salt and pepp...
# 2231139  ["150 grams Daikon radish", "1 tbsp Sesame oil...
# 2231140  ["1 cup apple cider", "6 tablespoons sugar", "...
# 2231141  ["1 pound ground veal", "1/2 pound sweet Itali...
#
#                                                 directions  \
# 0        ["In a heavy 2-quart saucepan, mix brown sugar...
# 1        ["Place chipped beef on bottom of baking dish....
# 2        ["In a slow cooker, combine all ingredients. C...
# 3        ["Boil and debone chicken.", "Put bite size pi...
# 4        ["Combine first four ingredients and press in ...
# ...                                                    ...
# 2231137  ["Spread hazelnut spread on 1 side of each tor...
# 2231138  ["Boil eggs on medium for 30mins.", "Then cool...
# 2231139  ["Julienne the daikon and squeeze out the exce...
# 2231140  ["In a large bowl, mix the apple cider with 4 ...
# 2231141  ["Preheat the oven to 350.", "In a bowl, mix t...
#
#                                                       link     source  \
# 0           www.cookbooks.com/Recipe-Details.aspx?id=44874   Gathered
# 1          www.cookbooks.com/Recipe-Details.aspx?id=699419   Gathered
# 2           www.cookbooks.com/Recipe-Details.aspx?id=10570   Gathered
# 3          www.cookbooks.com/Recipe-Details.aspx?id=897570   Gathered
# 4          www.cookbooks.com/Recipe-Details.aspx?id=659239   Gathered
# ...                                                    ...        ...
# 2231137  www.foodnetwork.com/recipes/sunny-anderson/sun...  Recipes1M
# 2231138           cookpad.com/us/recipes/355411-devil-eggs  Recipes1M
# 2231139  cookpad.com/us/recipes/153324-extremely-easy-a...  Recipes1M
# 2231140                cooking.nytimes.com/recipes/1015164  Recipes1M
# 2231141  www.foodandwine.com/recipes/polpette-spicy-tom...  Recipes1M
#
#                                                        NER  \
# 0        ["bite size shredded rice biscuits", "vanilla"...
# 1        ["cream of mushroom soup", "beef", "sour cream...
# 2        ["frozen corn", "pepper", "cream cheese", "gar...
# 3        ["chicken gravy", "cream of mushroom soup", "c...
# 4        ["graham cracker crumbs", "powdered sugar", "p...
# ...                                                    ...
# 2231137  ["chocolate hazelnut spread", "marshmallows", ...
# 2231138  ["choice", "miracle whip", "eggs", "relish", "...
# 2231139  ["soy sauce", "radish", "white sesame seeds", ...
# 2231140  ["apple cider", "egg", "sugar", "freshly groun...
# 2231141  ["freshly grated pecorino romano cheese", "tom...
#
#                         site
# 0          www.cookbooks.com
# 1          www.cookbooks.com
# 2          www.cookbooks.com
# 3          www.cookbooks.com
# 4          www.cookbooks.com
# ...                      ...
# 2231137  www.foodnetwork.com
# 2231138          cookpad.com
# 2231139          cookpad.com
# 2231140  cooking.nytimes.com
# 2231141  www.foodandwine.com
#
# [2231142 rows x 7 columns]

# %%
# Extract relevant columns
selected_columns = ['title', 'ingredients', 'directions', 'link', 'NER']
df_2M = df_2M[selected_columns]

# %%
# Drop duplicate recipes
df_2M = df_2M.drop_duplicates(subset=['title', 'directions'])

# %%
df_2M.head()
# Out:
#                    title                                        ingredients  \
# 0    No-Bake Nut Cookies  ["1 c. firmly packed brown sugar", "1/2 c. eva...
# 1  Jewell Ball'S Chicken  ["1 small jar chipped beef, cut up", "4 boned ...
# 2            Creamy Corn  ["2 (16 oz.) pkg. frozen corn", "1 (8 oz.) pkg...
# 3          Chicken Funny  ["1 large whole chicken", "2 (10 1/2 oz.) cans...
# 4   Reeses Cups(Candy)    ["1 c. peanut butter", "3/4 c. graham cracker ...
#
#                                           directions  \
# 0  ["In a heavy 2-quart saucepan, mix brown sugar...
# 1  ["Place chipped beef on bottom of baking dish....
# 2  ["In a slow cooker, combine all ingredients. C...
# 3  ["Boil and debone chicken.", "Put bite size pi...
# 4  ["Combine first four ingredients and press in ...
#
#                                               link  \
# 0   www.cookbooks.com/Recipe-Details.aspx?id=44874
# 1  www.cookbooks.com/Recipe-Details.aspx?id=699419
# 2   www.cookbooks.com/Recipe-Details.aspx?id=10570
# 3  www.cookbooks.com/Recipe-Details.aspx?id=897570
# 4  www.cookbooks.com/Recipe-Details.aspx?id=659239
#
#                                                  NER
# 0  ["bite size shredded rice biscuits", "vanilla"...
# 1  ["cream of mushroom soup", "beef", "sour cream...
# 2  ["frozen corn", "pepper", "cream cheese", "gar...
# 3  ["chicken gravy", "cream of mushroom soup", "c...
# 4  ["graham cracker crumbs", "powdered sugar", "p...

# %%
# Convert strings to lists
str_list_cols = ['ingredients', 'directions', 'NER']
for col in str_list_cols:
    df_2M[col] = df_2M[col].apply(
        lambda x: ast.literal_eval(x) if isinstance(x, str) else np.nan
    )

# %%
df_2M.isna().sum()
# Out:
# title          1
# ingredients    0
# directions     0
# link           0
# NER            0
# dtype: int64

# %% [markdown]
# ### Merge the two datasets

# %%
df_merged = pd.merge(df_recipes2, df_2M, left_on='Name', right_on='title', how='left')

# %%
df_merged.head()
# Out:
#                                 Name      AuthorName CookTime PrepTime  \
# 0  Low-Fat Berry Blue Frozen Dessert          Dancer    PT24H    PT45M
# 1                            Biryani        elly9812    PT25M     PT4H
# 2                            Biryani        elly9812    PT25M     PT4H
# 3                            Biryani        elly9812    PT25M     PT4H
# 4                      Best Lemonade  Stephen Little     PT5M    PT30M
#
#   TotalTime                                        Description  \
# 0  PT24H45M  Make and share this Low-Fat Berry Blue Frozen ...
# 1   PT4H25M  Make and share this Biryani recipe from Food.com.
# 2   PT4H25M  Make and share this Biryani recipe from Food.com.
# 3   PT4H25M  Make and share this Biryani recipe from Food.com.
# 4     PT35M  This is from one of my  first Good House Keepi...
#
#                                               Images   RecipeCategory  \
# 0  https://img.sndimg.com/food/image/upload/w_555...  Frozen Desserts
# 1  https://img.sndimg.com/food/image/upload/w_555...   Chicken Breast
# 2  https://img.sndimg.com/food/image/upload/w_555...   Chicken Breast
# 3  https://img.sndimg.com/food/image/upload/w_555...   Chicken Breast
# 4  https://img.sndimg.com/food/image/upload/w_555...        Beverages
#
#                                             Keywords  \
# 0  [Dessert, Low Protein, Low Cholesterol, Health...
# 1  [Chicken Thigh & Leg, Chicken, Poultry, Meat, ...
# 2  [Chicken Thigh & Leg, Chicken, Poultry, Meat, ...
# 3  [Chicken Thigh & Leg, Chicken, Poultry, Meat, ...
# 4  [Low Protein, Low Cholesterol, Healthy, Summer...
#
#                           RecipeIngredientQuantities  ... FatContent  \
# 0                                     [4, 1⁄4, 1, 1]  ...        2.5
# 1  [1, 4, 2, 2, 8, 1⁄4, 8, 1⁄2, 1, 1, 1⁄4, 1⁄4, 1...  ...       58.8
# 2  [1, 4, 2, 2, 8, 1⁄4, 8, 1⁄2, 1, 1, 1⁄4, 1⁄4, 1...  ...       58.8
# 3  [1, 4, 2, 2, 8, 1⁄4, 8, 1⁄2, 1, 1, 1⁄4, 1⁄4, 1...  ...       58.8
# 4                 [1 1⁄2, 1, None, 1 1⁄2, None, 3⁄4]  ...        0.2
#
#    SugarContent  ProteinContent  RecipeServings  \
# 0          30.2             3.2             4.0
# 1          20.4            63.4             6.0
# 2          20.4            63.4             6.0
# 3          20.4            63.4             6.0
# 4          77.2             0.3             4.0
#
#                                   RecipeInstructions  \
# 0  [Toss 2 cups berries with sugar., Let stand fo...
# 1  [Soak saffron in warm milk for 5 minutes and p...
# 2  [Soak saffron in warm milk for 5 minutes and p...
# 3  [Soak saffron in warm milk for 5 minutes and p...
# 4  [Into a 1 quart Jar with tight fitting lid, pu...
#
#                                title  \
# 0  Low-Fat Berry Blue Frozen Dessert
# 1                            Biryani
# 2                            Biryani
# 3                            Biryani
# 4                      Best Lemonade
#
#                                          ingredients  \
# 0  [4 cups blueberries, fresh or frozen, 1/4 cup ...
# 1  [1/2 lb. meat or chicken, cut in pieces, 1/2 l...
# 2  [1 tablespoon saffron, 4 teaspoons milk, warm,...
# 3  [2 cups basmati rice, 34 kg chicken piece, 12 ...
# 4  [1 1/2 c. sugar, 1 Tbsp. lemon peel, finely gr...
#
#                                           directions  \
# 0  [Toss 2 cups berries with sugar., Let stand fo...
# 1  [Marinate meat or chicken in thick yogurt for ...
# 2  [Soak saffron in warm milk for 5 minutes and p...
# 3  [Mix tomato puree, yogurt, ginger garlic paste...
# 4  [In 1-quart jar with tight fitting lid, shake ...
#
#                                                 link  \
# 0  www.food.com/recipe/low-fat-berry-blue-frozen-...
# 1    www.cookbooks.com/Recipe-Details.aspx?id=548876
# 2                     www.food.com/recipe/biryani-39
# 3                 www.food.com/recipe/biryani-484928
# 4    www.cookbooks.com/Recipe-Details.aspx?id=293155
#
#                                                  NER
# 0  [blueberries, sugar, vanilla yogurt, lemon juice]
# 1  [meat, ginger, cinnamon, cloves, onion, thick ...
# 2  [tomatoes, basmati rice, coriander seed, eggs,...
# 3  [oil, basmati rice, cumin powder, tomato puree...
# 4  [sugar, lemon juice, cold water, very hot wate...
#
# [5 rows x 23 columns]

# %%
df_merged.shape[0]
# Out:
# 1334836

# %% [markdown]
# #### Keep the identical recipes based on the instructions

# %%
filtered_df = df_merged[
    df_merged['RecipeInstructions'].apply(lambda x: x[0] if isinstance(x, list) and len(x) > 0 else None) ==
    df_merged['directions'].apply(lambda x: x[0] if isinstance(x, list) and len(x) > 0 else None)
].reset_index(drop=True)

# %%
filtered_df
# Out:
#                                              Name   AuthorName CookTime  \
# 0               Low-Fat Berry Blue Frozen Dessert       Dancer    PT24H
# 1                                         Biryani     elly9812    PT25M
# 2                                    Cabbage Soup    Duckie067    PT30M
# 3                                    Cabbage Soup    Duckie067    PT30M
# 4      Buttermilk Pie With Gingersnap Crumb Crust    tristitia    PT50M
# ...                                           ...          ...      ...
# 47378            Korean Chicken Porridge (Dakjuk)       PanNan    PT40M
# 47379                      Grilled Cuban Sandwich   Bonnie G 2    PT10M
# 47380        Boulets Liegeois (Belgian Meatballs)  Chef PotPie  PT1H30M
# 47381                         Cuban Mojo Potatoes       PanNan    PT45M
# 47382                      Mary Pickford Cocktail     momaphet     PT0M
#
#       PrepTime TotalTime                                        Description  \
# 0        PT45M  PT24H45M  Make and share this Low-Fat Berry Blue Frozen ...
# 1         PT4H   PT4H25M  Make and share this Biryani recipe from Food.com.
# 2        PT20M     PT50M  Make and share this Cabbage Soup recipe from F...
# 3        PT20M     PT50M  Make and share this Cabbage Soup recipe from F...
# 4        PT30M   PT1H20M  Make and share this Buttermilk Pie With Ginger...
# ...        ...       ...                                                ...
# 47378     PT1H   PT1H40M  Porridge is very popular as a breakfast food i...
# 47379    PT10M     PT20M  Once I made Cuban bread needed to find an auth...
# 47380    PT10M   PT1H40M  Belgian meatballs swimming in an apple and oni...
# 47381    PT15M      PT1H  Make and share this Cuban Mojo Potatoes recipe...
# 47382     PT3M      PT3M  This cocktail was developed for Mary Pickford ...
#
#                                                   Images   RecipeCategory  \
# 0      https://img.sndimg.com/food/image/upload/w_555...  Frozen Desserts
# 1      https://img.sndimg.com/food/image/upload/w_555...   Chicken Breast
# 2      https://img.sndimg.com/food/image/upload/w_555...        Vegetable
# 3      https://img.sndimg.com/food/image/upload/w_555...        Vegetable
# 4      https://img.sndimg.com/food/image/upload/w_555...              Pie
# ...                                                  ...              ...
# 47378  https://img.sndimg.com/food/image/upload/w_555...        Breakfast
# 47379  https://img.sndimg.com/food/image/upload/w_555...              Ham
# 47380  https://img.sndimg.com/food/image/upload/w_555...          Belgian
# 47381  https://img.sndimg.com/food/image/upload/w_555...            Cuban
# 47382  https://img.sndimg.com/food/image/upload/w_555...        Beverages
#
#                                                 Keywords  \
# 0      [Dessert, Low Protein, Low Cholesterol, Health...
# 1      [Chicken Thigh & Leg, Chicken, Poultry, Meat, ...
# 2      [Low Protein, Vegan, Low Cholesterol, Healthy,...
# 3      [Low Protein, Vegan, Low Cholesterol, Healthy,...
# 4         [Dessert, Healthy, Weeknight, Oven, < 4 Hours]
# ...                                                  ...
# 47378                         [Korean, Asian, < 4 Hours]
# 47379                            [Pork, Meat, < 30 Mins]
# 47380                              [European, < 4 Hours]
# 47381  [Caribbean, Low Protein, Low Cholesterol, Heal...
# 47382  [Low Protein, Low Cholesterol, Healthy, < 15 M...
#
#                               RecipeIngredientQuantities  ... FatContent  \
# 0                                         [4, 1⁄4, 1, 1]  ...        2.5
# 1      [1, 4, 2, 2, 8, 1⁄4, 8, 1⁄2, 1, 1, 1⁄4, 1⁄4, 1...  ...       58.8
# 2                                       [46, 4, 1, 2, 1]  ...        0.4
# 3                                       [46, 4, 1, 2, 1]  ...        0.4
# 4                 [3⁄4, 1, 1, 2, 3, 1⁄4, 1, 1⁄2, 1⁄2, 2]  ...        7.1
# ...                                                  ...  ...        ...
# 47378                 [1, 6, 1 1⁄2, 1, 1, 3 -4, 2, 2, 1]  ...       11.9
# 47379                    [1, 1⁄4, 3, 1 1⁄2, 1 1⁄2, 1, 1]  ...       32.8
# 47380  [1, 1, 4, 1, 1, 2, None, None, 2, 2, 3, 2, 1, ...  ...       37.7
# 47381              [1 1⁄2, 1, 1⁄2, 1⁄4, 1, 6, 3, 1, 1⁄2]  ...       13.8
# 47382                                       [2, 2, 1, 1]  ...        0.1
#
#        SugarContent  ProteinContent  RecipeServings  \
# 0              30.2             3.2             4.0
# 1              20.4            63.4             6.0
# 2              17.7             4.3             4.0
# 3              17.7             4.3             4.0
# 4              24.7             4.2             8.0
# ...             ...             ...             ...
# 47378           7.0            13.2             4.0
# 47379           1.3            53.2             8.0
# 47380          20.5            33.1             6.0
# 47381           3.2             4.1             4.0
# 47382          16.9             0.2             1.0
#
#                                       RecipeInstructions  \
# 0      [Toss 2 cups berries with sugar., Let stand fo...
# 1      [Soak saffron in warm milk for 5 minutes and p...
# 2      [Mix everything together and bring to a boil.,...
# 3      [Mix everything together and bring to a boil.,...
# 4      [Preheat oven to 350°F., Make pie crust, using...
# ...                                                  ...
# 47378  [Soak the rice for an hour and drain., Finely ...
# 47379  [Assemble the sandwich., Spread 2 tablespoons ...
# 47380  [Mix beef and pork together in a large bowl to...
# 47381  [Lay a sheet of aluminum foil on the counterto...
# 47382  [Pour all ingredients except the cherry into a...
#
#                                             title  \
# 0               Low-Fat Berry Blue Frozen Dessert
# 1                                         Biryani
# 2                                    Cabbage Soup
# 3                                    Cabbage Soup
# 4      Buttermilk Pie With Gingersnap Crumb Crust
# ...                                           ...
# 47378            Korean Chicken Porridge (Dakjuk)
# 47379                      Grilled Cuban Sandwich
# 47380        Boulets Liegeois (Belgian Meatballs)
# 47381                         Cuban Mojo Potatoes
# 47382                      Mary Pickford Cocktail
#
#                                              ingredients  \
# 0      [4 cups blueberries, fresh or frozen, 1/4 cup ...
# 1      [1 tablespoon saffron, 4 teaspoons milk, warm,...
# 2      [46 ounces plain tomato juice, 4 cups cabbage,...
# 3      [1 head cabbage, chopped, 1 onion, diced, 4 ce...
# 4      [3/4 cup sugar, 1 tablespoon margarine, 1 egg,...
# ...                                                  ...
# 47378  [1 cup short-grain rice (or sweet rice glutino...
# 47379  [1 loaf Cuban bread, sliced lengthwise, 1/4 cu...
# 47380  [For the meatballs, 1 lb ground beef, 1 lb gro...
# 47381  [1 1/2 lbs yukon gold potatoes, large dice, 1 ...
# 47382  [2 ounces light rum, 2 ounces pineapple juice,...
#
#                                               directions  \
# 0      [Toss 2 cups berries with sugar., Let stand fo...
# 1      [Soak saffron in warm milk for 5 minutes and p...
# 2      [Mix everything together and bring to a boil.,...
# 3      [Mix everything together and bring to a boil.,...
# 4      [Preheat oven to 350°F., Make pie crust, using...
# ...                                                  ...
# 47378  [Soak the rice for an hour and drain., Finely ...
# 47379  [Assemble the sandwich., Spread 2 tablespoons ...
# 47380  [Mix beef and pork together in a large bowl to...
# 47381  [Lay a sheet of aluminum foil on the counterto...
# 47382  [Pour all ingredients except the cherry into a...
#
#                                                     link  \
# 0      www.food.com/recipe/low-fat-berry-blue-frozen-...
# 1                         www.food.com/recipe/biryani-39
# 2                    www.food.com/recipe/cabbage-soup-42
# 3                www.food.com/recipe/cabbage-soup-204921
# 4      www.food.com/recipe/buttermilk-pie-with-ginger...
# ...                                                  ...
# 47378  www.food.com/recipe/korean-chicken-porridge-da...
# 47379  www.food.com/recipe/grilled-cuban-sandwich-538973
# 47380  www.food.com/recipe/boulets-liegeois-belgian-m...
# 47381     www.food.com/recipe/cuban-mojo-potatoes-539090
# 47382  www.food.com/recipe/mary-pickford-cocktail-539102
#
#                                                      NER
# 0      [blueberries, sugar, vanilla yogurt, lemon juice]
# 1      [tomatoes, basmati rice, coriander seed, eggs,...
# 2        [cabbage, onion, celery, carrots, tomato juice]
# 3      [cabbage, tomato paste, pepper, onion, mushroo...
# 4      [buttermilk, gingersnap crumbs, egg, sugar, gr...
# ...                                                  ...
# 47378  [scallions, sesame seeds, short-grain rice, ce...
# 47379  [yellow mustard, swiss cheese, ham, dill pickl...
# 47380  [ground pork, red wine vinegar, beef stock, un...
# 47381  [gold potatoes, scallions, cilantro, red peppe...
# 47382  [light rum, grenadine, pineapple juice, marasc...
#
# [47383 rows x 23 columns]

# %% [markdown]
# #### Drop duplicate columns

# %%
columns_to_drop = ['Name', 'RecipeIngredientQuantities', 'RecipeIngredientParts', 'RecipeInstructions']
df = filtered_df.drop(columns=columns_to_drop)

# %%
df
# Out:
#         AuthorName CookTime PrepTime TotalTime  \
# 0           Dancer    PT24H    PT45M  PT24H45M
# 1         elly9812    PT25M     PT4H   PT4H25M
# 2        Duckie067    PT30M    PT20M     PT50M
# 3        Duckie067    PT30M    PT20M     PT50M
# 4        tristitia    PT50M    PT30M   PT1H20M
# ...            ...      ...      ...       ...
# 47378       PanNan    PT40M     PT1H   PT1H40M
# 47379   Bonnie G 2    PT10M    PT10M     PT20M
# 47380  Chef PotPie  PT1H30M    PT10M   PT1H40M
# 47381       PanNan    PT45M    PT15M      PT1H
# 47382     momaphet     PT0M     PT3M      PT3M
#
#                                              Description  \
# 0      Make and share this Low-Fat Berry Blue Frozen ...
# 1      Make and share this Biryani recipe from Food.com.
# 2      Make and share this Cabbage Soup recipe from F...
# 3      Make and share this Cabbage Soup recipe from F...
# 4      Make and share this Buttermilk Pie With Ginger...
# ...                                                  ...
# 47378  Porridge is very popular as a breakfast food i...
# 47379  Once I made Cuban bread needed to find an auth...
# 47380  Belgian meatballs swimming in an apple and oni...
# 47381  Make and share this Cuban Mojo Potatoes recipe...
# 47382  This cocktail was developed for Mary Pickford ...
#
#                                                   Images   RecipeCategory  \
# 0      https://img.sndimg.com/food/image/upload/w_555...  Frozen Desserts
# 1      https://img.sndimg.com/food/image/upload/w_555...   Chicken Breast
# 2      https://img.sndimg.com/food/image/upload/w_555...        Vegetable
# 3      https://img.sndimg.com/food/image/upload/w_555...        Vegetable
# 4      https://img.sndimg.com/food/image/upload/w_555...              Pie
# ...                                                  ...              ...
# 47378  https://img.sndimg.com/food/image/upload/w_555...        Breakfast
# 47379  https://img.sndimg.com/food/image/upload/w_555...              Ham
# 47380  https://img.sndimg.com/food/image/upload/w_555...          Belgian
# 47381  https://img.sndimg.com/food/image/upload/w_555...            Cuban
# 47382  https://img.sndimg.com/food/image/upload/w_555...        Beverages
#
#                                                 Keywords  AggregatedRating  \
# 0      [Dessert, Low Protein, Low Cholesterol, Health...               4.5
# 1      [Chicken Thigh & Leg, Chicken, Poultry, Meat, ...               3.0
# 2      [Low Protein, Vegan, Low Cholesterol, Healthy,...               4.5
# 3      [Low Protein, Vegan, Low Cholesterol, Healthy,...               4.5
# 4         [Dessert, Healthy, Weeknight, Oven, < 4 Hours]               4.0
# ...                                                  ...               ...
# 47378                         [Korean, Asian, < 4 Hours]               5.0
# 47379                            [Pork, Meat, < 30 Mins]               5.0
# 47380                              [European, < 4 Hours]               5.0
# 47381  [Caribbean, Low Protein, Low Cholesterol, Heal...               5.0
# 47382  [Low Protein, Low Cholesterol, Healthy, < 15 M...               5.0
#
#        Calories  FatContent  SugarContent  ProteinContent  RecipeServings  \
# 0         170.9         2.5          30.2             3.2             4.0
# 1        1110.7        58.8          20.4            63.4             6.0
# 2         103.6         0.4          17.7             4.3             4.0
# 3         103.6         0.4          17.7             4.3             4.0
# 4         228.0         7.1          24.7             4.2             8.0
# ...         ...         ...           ...             ...             ...
# 47378     386.2        11.9           7.0            13.2             4.0
# 47379     532.2        32.8           1.3            53.2             8.0
# 47380     627.9        37.7          20.5            33.1             6.0
# 47381     293.2        13.8           3.2             4.1             4.0
# 47382     220.6         0.1          16.9             0.2             1.0
#
#                                             title  \
# 0               Low-Fat Berry Blue Frozen Dessert
# 1                                         Biryani
# 2                                    Cabbage Soup
# 3                                    Cabbage Soup
# 4      Buttermilk Pie With Gingersnap Crumb Crust
# ...                                           ...
# 47378            Korean Chicken Porridge (Dakjuk)
# 47379                      Grilled Cuban Sandwich
# 47380        Boulets Liegeois (Belgian Meatballs)
# 47381                         Cuban Mojo Potatoes
# 47382                      Mary Pickford Cocktail
#
#                                              ingredients  \
# 0      [4 cups blueberries, fresh or frozen, 1/4 cup ...
# 1      [1 tablespoon saffron, 4 teaspoons milk, warm,...
# 2      [46 ounces plain tomato juice, 4 cups cabbage,...
# 3      [1 head cabbage, chopped, 1 onion, diced, 4 ce...
# 4      [3/4 cup sugar, 1 tablespoon margarine, 1 egg,...
# ...                                                  ...
# 47378  [1 cup short-grain rice (or sweet rice glutino...
# 47379  [1 loaf Cuban bread, sliced lengthwise, 1/4 cu...
# 47380  [For the meatballs, 1 lb ground beef, 1 lb gro...
# 47381  [1 1/2 lbs yukon gold potatoes, large dice, 1 ...
# 47382  [2 ounces light rum, 2 ounces pineapple juice,...
#
#                                               directions  \
# 0      [Toss 2 cups berries with sugar., Let stand fo...
# 1      [Soak saffron in warm milk for 5 minutes and p...
# 2      [Mix everything together and bring to a boil.,...
# 3      [Mix everything together and bring to a boil.,...
# 4      [Preheat oven to 350°F., Make pie crust, using...
# ...                                                  ...
# 47378  [Soak the rice for an hour and drain., Finely ...
# 47379  [Assemble the sandwich., Spread 2 tablespoons ...
# 47380  [Mix beef and pork together in a large bowl to...
# 47381  [Lay a sheet of aluminum foil on the counterto...
# 47382  [Pour all ingredients except the cherry into a...
#
#                                                     link  \
# 0      www.food.com/recipe/low-fat-berry-blue-frozen-...
# 1                         www.food.com/recipe/biryani-39
# 2                    www.food.com/recipe/cabbage-soup-42
# 3                www.food.com/recipe/cabbage-soup-204921
# 4      www.food.com/recipe/buttermilk-pie-with-ginger...
# ...                                                  ...
# 47378  www.food.com/recipe/korean-chicken-porridge-da...
# 47379  www.food.com/recipe/grilled-cuban-sandwich-538973
# 47380  www.food.com/recipe/boulets-liegeois-belgian-m...
# 47381     www.food.com/recipe/cuban-mojo-potatoes-539090
# 47382  www.food.com/recipe/mary-pickford-cocktail-539102
#
#                                                      NER
# 0      [blueberries, sugar, vanilla yogurt, lemon juice]
# 1      [tomatoes, basmati rice, coriander seed, eggs,...
# 2        [cabbage, onion, celery, carrots, tomato juice]
# 3      [cabbage, tomato paste, pepper, onion, mushroo...
# 4      [buttermilk, gingersnap crumbs, egg, sugar, gr...
# ...                                                  ...
# 47378  [scallions, sesame seeds, short-grain rice, ce...
# 47379  [yellow mustard, swiss cheese, ham, dill pickl...
# 47380  [ground pork, red wine vinegar, beef stock, un...
# 47381  [gold potatoes, scallions, cilantro, red peppe...
# 47382  [light rum, grenadine, pineapple juice, marasc...
#
# [47383 rows x 19 columns]

# %% [markdown]
# ## Cleaning

# %% [markdown]
# ### Columns CookTime, PrepTime and TotalTime

# %%
def duration_to_minutes(duration: str) -> float:
    """
    Function to convert ISO 8601 durations to total minutes

    Args:
        - duration (str): duration in ISO 8601 format (ex: 'PT1H30M')
    """
    if pd.isna(duration): 
        return np.nan

    hours = re.search(r'(\d+)H', duration)
    minutes = re.search(r'(\d+)M', duration)
    
    total_minutes = 0
    if hours:
        total_minutes += int(hours.group(1)) * 60
    if minutes:
        total_minutes += int(minutes.group(1))
    
    return total_minutes

# %%
def duration_to_readable_format(duration: str) -> str:
    """
    Function to convert ISO 8601 durations to a more readable format
    
    Args:
        - duration (str): duration in ISO 8601 format (ex: 'PT1H30M')

    Example output: "1 h 30 min"
    """
    if pd.isna(duration): 
        return np.nan

    hours = re.search(r'(\d+)H', duration)
    minutes = re.search(r'(\d+)M', duration)
    
    result = []
    if hours:
        result.append(f"{int(hours.group(1))} h")
    if minutes:
        result.append(f"{int(minutes.group(1))} min")
    
    return ' '.join(result)

# %%
duration_to_readable_format('PT1H30M')
# Out:
# '1 h 30 min'

# %%
columns = ['CookTime', 'PrepTime', 'TotalTime']
for col in columns:
    df[f'{col}_min'] = df[col].apply(duration_to_minutes)

# %% [markdown]
# ### Columns RecipeCategory and Keywords

# %%
df['RecipeCategory'].value_counts()
# Out:
# RecipeCategory
# Dessert            4782
# Lunch/Snacks       3520
# Beverages          3224
# Vegetable          3123
# One Dish Meal      2491
#                    ...
# Moose                 1
# Ecuadorean            1
# Small Appliance       1
# Nigerian              1
# Belgian               1
# Name: count, Length: 247, dtype: int64

# %%
df['RecipeCategory'].nunique()
# Out:
# 247

# %% [markdown]
# #### Group categories

# %% [markdown]
# - Dessert
# - Main course
# - Breakfast
# - Beverages

# %%
from collections import Counter
all_keywords = [keyword for keywords in df['Keywords'] for keyword in keywords]
keyword_counts = Counter(all_keywords)
keyword_counts_df = pd.DataFrame(keyword_counts.items(), columns=['Keyword', 'Count'])
keyword_counts_df = keyword_counts_df.sort_values(by='Count', ascending=False)

# %%
keyword_counts_df['Keyword'].unique()
# Out:
# array(['Easy', '< 60 Mins', '< 30 Mins', '< 15 Mins', 'Meat', 'Healthy',
#        '< 4 Hours', 'Low Cholesterol', 'Vegetable', 'Beginner Cook',
#        'Oven', 'Low Protein', 'Fruit', 'Inexpensive', 'For Large Groups',
#        'Kid Friendly', 'Poultry', 'European', 'Stove Top', 'Brunch',
#        'Weeknight', 'Dessert', 'Chicken', 'High In...', 'Free Of...',
#        'Asian', 'Summer', 'Sweet', 'Breads', 'Cookie & Brownie', 'Cheese',
#        'Potluck', 'Vegan', 'Very Low Carbs', 'Savory', 'High Protein',
#        'Small Appliance', 'Lunch/Snacks', 'Spicy', 'Winter', 'Berries',
#        'Christmas', 'Mexican', 'Tropical Fruits', 'No Cook', 'Nuts',
#        'Beans', 'Beverages', 'Canadian', 'Pork', 'Egg Free', 'Breakfast',
#        'Grains', 'Apple', 'Citrus', 'Spring', 'Rice', 'Potato',
#        'Refrigerator', 'Lactose Free', 'Thanksgiving', 'Toddler Friendly',
#        'Kosher', 'Southwestern U.S.', 'Australian', 'Onions', 'Greens',
#        'African', 'Strawberry', 'From Scratch', 'Chicken Breast',
#        'Indian', 'Microwave', 'Greek', 'Peppers', 'Broil/Grill',
#        'Caribbean', 'Pineapple', 'Camping', 'Stir Fry', 'Lemon', 'Mixer',
#        'Chinese', 'Southwest Asia (middle East)', 'Tex Mex', 'Coconut',
#        'Oranges', 'Scandinavian', 'One Dish Meal', 'Freezer', 'German',
#        'South American', 'Roast', 'Raspberries', 'Thai', 'Corn',
#        'Spanish', 'Cajun', 'Bread Machine', 'Tuna', 'Spinach', 'Moroccan',
#        'Lime', 'Black Beans', 'Deep Fried', 'Quick Breads', 'Halloween',
#        "St. Patrick's Day", 'Ham', 'Creole', 'Spaghetti', 'Mango',
#        'Chicken Thigh & Leg', 'New Zealand', 'Melons', 'Japanese',
#        'Long Grain Rice', 'Scottish', 'Pears', 'Soy/Tofu', 'Hanukkah',
#        'Lentil', 'White Rice', 'Cherries', 'Hawaiian', 'Lamb/Sheep',
#        'Steam', 'Crab', 'Cauliflower', 'Steak', 'Swedish', 'Swiss',
#        'Shakes', 'Polish', 'Baking', 'Portuguese', 'Penne', 'Roast Beef',
#        'Brown Rice', 'Yam/Sweet Potato', 'Whole Chicken', 'Russian',
#        'Hungarian', 'Lebanese', 'Grapes', 'Ramadan', 'Brazilian',
#        'Wild Game', 'South African', 'Cuban', 'Canning', 'High Fiber',
#        'Danish', 'Turkish', 'Korean', 'Peanut Butter', 'Vietnamese',
#        'Birthday', 'Short Grain Rice', 'Indonesian', 'Finnish', 'Dutch',
#        'Belgian', 'Polynesian', 'Pasta Shells', 'Filipino', 'Kiwifruit',
#        'Stew', 'Egyptian', 'Papaya', 'Norwegian', 'Pressure Cooker',
#        'Frozen Desserts', 'Oysters', 'Szechuan', 'Turkey Breasts',
#        'Palestinian', 'Dairy Free Foods', 'Plums', 'Welsh', 'Tilapia',
#        'Austrian', 'Malaysian', 'No Shell Fish', 'Czech', 'Chard', 'Duck',
#        'Yeast Breads', 'Venezuelan', 'Sauces', 'Candy',
#        'Medium Grain Rice', 'Peruvian', 'Halibut', 'Pakistani',
#        'Puerto Rican', 'Avocado', 'Native American', 'Icelandic',
#        'Pumpkin', 'Pennsylvania Dutch', 'Colombian', 'Chilean', 'Veal',
#        'Costa Rican', 'Salad Dressings', 'Dehydrator', 'Smoothies',
#        'Lobster', 'Homeopathy/Remedies', 'Crawfish', 'Labor Day',
#        'Cheesecake', 'Iraqi', 'Pie', 'Guatemalan', 'Mussels', 'Cantonese',
#        'Beef Liver', 'Nepalese', 'Hunan', 'Memorial Day', 'Ethiopian',
#        'Catfish', 'Spreads', 'Gelatin', 'Reynolds Wrap Contest',
#        'Punch Beverage', 'Deer', 'Squid', 'Chicken Livers', 'Cambodian',
#        'Manicotti', 'Nigerian', 'Rabbit', 'Bar Cookie', 'Savory Pies',
#        'Sudanese', 'Whitefish', 'Beef Organ Meats', 'Bass', 'Stocks',
#        'College Food', 'Chocolate Chip Cookies', 'Mahi Mahi', 'Tempeh',
#        'Mongolian', 'Trout', 'Ecuadorean', 'Collard Greens', 'Artichoke',
#        'Ice Cream', 'Chowders', 'Somalian', 'Moose', 'Household Cleaner',
#        'Halloween Cocktail', 'Duck Breasts', 'Oatmeal', 'Pheasant',
#        'Orange Roughy', 'Honduran', 'Elk', 'Whole Turkey',
#        'Served Hot New Years', 'Meatloaf', 'Octopus', 'Bath/Beauty',
#        'Pasta Elbow'], dtype=object)

# %%
trigger_patterns = {
    'Main Course': r'lunch|meal|meat|chicken|beef|pork|steak|turkey|duck|fish|salmon|lamb|crab|shrimp|lobster|tuna|vegetable|potato|rice|noodle|pasta|penne|spaghetti|macaroni|linguine|pizza|quiche|bean|lentil|onion|soup|stew|dressing',
    'Breakfast': r'breakfast',
    'Dessert': r'dessert|cake|cookie|brownie|muffin|biscuit|babka|sweet|candy|sugar|banana',
    'Beverages': r'beverage|cocktail|smoothie|lemonade|coffee',
}

# %%
def assign_category(row):
    keywords = row['Keywords']
    title = row['title'] 
    category = row['RecipeCategory']
    ingredients = row['NER']

    # Check the Keywords first
    if keywords is not None and isinstance(keywords, (list, np.ndarray)):
        keywords_list = [str(keyword) for keyword in keywords if keyword is not None and not pd.isna(keyword)]
        if keywords_list:
            keywords_str = ' '.join(keywords_list).lower()
            for cat, pattern in trigger_patterns.items():
                if re.search(pattern, keywords_str):
                    return cat
    
    # Check the title
    if title is not None and isinstance(title, str):
        title_lower = title.lower()
        for cat, pattern in trigger_patterns.items():
            if re.search(pattern, title_lower):
                return cat
    
    # Check the RecipeCategory
    if category is not None and isinstance(category, str):
        category_lower = category.lower()
        for cat, pattern in trigger_patterns.items():
            if re.search(pattern, category_lower):
                return cat
    
    # # Check the ingredients
    # if ingredients is not None and isinstance(ingredients, str):
    #     ingredients_list = ast.literal_eval(ingredients)
    #     if isinstance(ingredients_list, list):
    #         ingredients_str = ' '.join(map(str, ingredients_list)).lower()
    #         for cat, pattern in trigger_patterns.items():
    #             if re.search(pattern, ingredients_str):
    #                 return cat
    
    return row['RecipeCategory']

# %%
df['RecipeType'] = df.apply(assign_category, axis=1)

# %%
df['RecipeType'].nunique()
# Out:
# 144

# %%
df['RecipeType'].value_counts()[:50]
# Out:
# RecipeType
# Main Course         28122
# Dessert              9856
# Beverages            3399
# Breakfast            1626
# Breads                392
# Yeast Breads          329
# Sauces                327
# Low Protein           301
# < 15 Mins             232
# Quick Breads          213
# Cheese                190
# < 30 Mins             151
# European              135
# Spreads               115
# Low Cholesterol       114
# < 60 Mins             104
# Mexican               102
# Fruit                 100
# Very Low Carbs         98
# Grains                 75
# Asian                  70
# Scones                 61
# Tilapia                60
# Apple                  55
# Healthy                51
# Pineapple              44
# Chowders               41
# Kid Friendly           40
# High In...             33
# < 4 Hours              31
# Halibut                28
# Greek                  27
# Weeknight              27
# Brunch                 24
# Vegan                  24
# Canadian               23
# High Protein           23
# Strawberry             22
# Australian             22
# For Large Groups       22
# Potluck                19
# Trout                  19
# Japanese               18
# Berries                18
# Cajun                  18
# Chinese                17
# Oranges                17
# Moroccan               16
# Mahi Mahi              16
# Melons                 16
# Name: count, dtype: int64

# %%
df[['title', 'RecipeType', 'RecipeCategory', 'Keywords']][df['RecipeCategory']=='< 30 Mins'][:50]
# Out:
#                                            title   RecipeType RecipeCategory  \
# 18                                Anzac Biscuits      Dessert      < 30 Mins
# 19                                Anzac Biscuits      Dessert      < 30 Mins
# 91     Vegetarian Baked Stuffed Red Bell Peppers    < 30 Mins      < 30 Mins
# 158                                Hot Pizza Dip  Main Course      < 30 Mins
# 409                       Herbed Garlic Croutons    < 30 Mins      < 30 Mins
# 1243                  The Real Deal Deviled Eggs    < 30 Mins      < 30 Mins
# 1667                           Bratwurst Skillet    < 30 Mins      < 30 Mins
# 2037                         Creamy Dill Noodles  Main Course      < 30 Mins
# 2615                         Pasta With Scallops  Main Course      < 30 Mins
# 3026                                  Orzo Salad    < 30 Mins      < 30 Mins
# 3300                        Tomato-Basil Squares    < 30 Mins      < 30 Mins
# 3327        15 Minutes Creamy Fettuccine Alfredo    < 30 Mins      < 30 Mins
# 3829                      Louisiana Baked Shrimp  Main Course      < 30 Mins
# 3871                              Tortilla Wraps    < 30 Mins      < 30 Mins
# 4559                       Barbecued Flank Steak  Main Course      < 30 Mins
# 4702                         Mixed Seafood Saute    < 30 Mins      < 30 Mins
# 4775                          Super Deviled Eggs    < 30 Mins      < 30 Mins
# 4781                              Baked Tomatoes    < 30 Mins      < 30 Mins
# 4823                Baked Cream Cheese Appetizer    < 30 Mins      < 30 Mins
# 4959                              Couscous Salad    < 30 Mins      < 30 Mins
# 5177                           Cape May Scallops    < 30 Mins      < 30 Mins
# 5179                        Vegetable Pasta Bake  Main Course      < 30 Mins
# 5563                               Won Ton Salad    < 30 Mins      < 30 Mins
# 5620                         Easy Taco Casserole    < 30 Mins      < 30 Mins
# 5735       Tomatoes With Cheese Sauce over Toast    < 30 Mins      < 30 Mins
# 6082                Brussels Sprouts with Pecans    < 30 Mins      < 30 Mins
# 6157                                 Capri Salad    < 30 Mins      < 30 Mins
# 6238                     Easiest Creamed Spinach    < 30 Mins      < 30 Mins
# 6594                 Garlic Shrimp (WW-4 points)  Main Course      < 30 Mins
# 6718                              Perfect Salmon  Main Course      < 30 Mins
# 6740                          Corny Chicken Soup  Main Course      < 30 Mins
# 7210                     Buttered Garlic Noodles  Main Course      < 30 Mins
# 8661                             Cocktail Shrimp  Main Course      < 30 Mins
# 8735                               Sole Francese    < 30 Mins      < 30 Mins
# 8740                        Avocado Stuffed Eggs    < 30 Mins      < 30 Mins
# 9315                  Low Fat Fettuccine Alfredo    < 30 Mins      < 30 Mins
# 9725          Legal Seafood Style Baked Scallops    < 30 Mins      < 30 Mins
# 10129                        Garlic Potato Tapas  Main Course      < 30 Mins
# 10808                                   Croutons    < 30 Mins      < 30 Mins
# 10882                    Swiss Stuffed Mushrooms    < 30 Mins      < 30 Mins
# 10940          Surprise Coated Crisp Fish Filets  Main Course      < 30 Mins
# 11186       Mediterranean Salad With Feta Cheese    < 30 Mins      < 30 Mins
# 11321                     Spinach Cheese Bundles    < 30 Mins      < 30 Mins
# 11863                             Crusted Salmon  Main Course      < 30 Mins
# 11956                  3 Step Fettuccine Alfredo    < 30 Mins      < 30 Mins
# 12079                       Garlic Lovin' Salmon  Main Course      < 30 Mins
# 12267                     Luscious Lobster Salad  Main Course      < 30 Mins
# 12755                                   Coleslaw    < 30 Mins      < 30 Mins
# 12777    Traditional English Tavern Creamed Corn    < 30 Mins      < 30 Mins
# 12823     Broiled  Shrimp With Herbed Mayonnaise  Main Course      < 30 Mins
#
#                                             Keywords
# 18                                            [Oven]
# 19                                            [Oven]
# 91                                            [Oven]
# 158                                           [Oven]
# 409                                           [Easy]
# 1243                 [Refrigerator, Stove Top, Easy]
# 1667                                     [Stove Top]
# 2037                                     [Stove Top]
# 2615                               [Stove Top, Easy]
# 3026                                          [Easy]
# 3300                              [For Large Groups]
# 3327                                          [Easy]
# 3829                                          [Easy]
# 3871               [For Large Groups, No Cook, Easy]
# 4559                                          [Easy]
# 4702                               [Stove Top, Easy]
# 4775                 [Refrigerator, Stove Top, Easy]
# 4781                                    [Oven, Easy]
# 4823                                    [Oven, Easy]
# 4959                        [Stove Top, Inexpensive]
# 5177                                          [Easy]
# 5179                                          [Easy]
# 5563                                          [Easy]
# 5620                                    [Oven, Easy]
# 5735                                          [Easy]
# 6082                                [Stir Fry, Easy]
# 6157                                          [Easy]
# 6238                                          [Easy]
# 6594                                     [Stove Top]
# 6718                                          [Easy]
# 6740                                          [Easy]
# 7210                               [Stove Top, Easy]
# 8661                                     [Stove Top]
# 8735                                          [Easy]
# 8740                              [For Large Groups]
# 9315                    [Stove Top, Small Appliance]
# 9725                                    [Oven, Easy]
# 10129                                         [Easy]
# 10808                                   [Oven, Easy]
# 10882                                         [Oven]
# 10940                                         [Easy]
# 11186                                         [Easy]
# 11321  [For Large Groups, Oven, Beginner Cook, Easy]
# 11863                                         [Easy]
# 11956                          [Beginner Cook, Easy]
# 12079                                         [Easy]
# 12267                                         [Easy]
# 12755                             [For Large Groups]
# 12777                                         [Easy]
# 12823                          [Beginner Cook, Easy]

# %% [markdown]
# Create a new binary column df['Begginer_Friendly'] that takes the value True when "Easy" is in df['Keywords'] False if not

# %%
# Find indices of recipes with "Easy" keyword
easy_recipe_indices = df[df['Keywords'].apply(lambda x: 'Easy' in x)].index

# Create a new column 'Beginner_Friendly' and set it to False initially
df['Beginner_Friendly'] = False

# Set the value to True for recipes with "Easy" keyword
df.loc[easy_recipe_indices, 'Beginner_Friendly'] = True

# %%
df['Beginner_Friendly'].value_counts(dropna=False)
# Out:
# Beginner_Friendly
# True     26742
# False    20641
# Name: count, dtype: int64

# %% [markdown]
# Create a new binary column df['TotalTime_range'] that takes the 3 values :
# - under30m if the value in df['TotalTime'] indicates under 30 minutes of preparation time
# - between30and60m if the value in df['TotalTime'] indicates between 30 minutes and 1 hour of preparation time
# - above60m if the value in df['TotalTime'] indicates more than 1 hour of preparation time

# %%
df["CookTime"]
# Out:
# 0          PT24H
# 1          PT25M
# 2          PT30M
# 3          PT30M
# 4          PT50M
#           ...
# 47378      PT40M
# 47379      PT10M
# 47380    PT1H30M
# 47381      PT45M
# 47382       PT0M
# Name: CookTime, Length: 47383, dtype: object

# %%
def categorize_time(time_str):
    """Categorizes a time string into three categories:

    - 'under30m' if the time is less than 30 minutes
    - 'between30and60m' if the time is between 30 and 60 minutes
    - 'above60m' if the time is more than 60 minutes

    Args:
        time_str: The time string in the format 'PTxxHx' or 'PTxxMx'.

    Returns:
        The category string.
    """

    if time_str in ["PT{}M".format(i) for i in range(0, 31)]:
        return 'under30m'
    elif time_str in ["PT{}M".format(i) for i in range(31, 61)]:
        return 'between30and60m'
    else:
        return 'above60m'

# %%
df['TotalTime_range'] = df['CookTime'].apply(categorize_time)

# %%
df[['TotalTime_range','CookTime']]
# Out:
#        TotalTime_range CookTime
# 0             above60m    PT24H
# 1             under30m    PT25M
# 2             under30m    PT30M
# 3             under30m    PT30M
# 4      between30and60m    PT50M
# ...                ...      ...
# 47378  between30and60m    PT40M
# 47379         under30m    PT10M
# 47380         above60m  PT1H30M
# 47381  between30and60m    PT45M
# 47382         under30m     PT0M
#
# [47383 rows x 2 columns]

# %% [markdown]
# Create a new binary column df['Begginer_Friendly'] that takes the value True when "Easy" is in df['Keywords'] False if not

# %%
# Find indices of recipes with "Easy" keyword
easy_recipe_indices = df[df['Keywords'].apply(lambda x: 'Easy' in x)].index

# Create a new column 'Beginner_Friendly' and set it to False initially
df['Beginner_Friendly'] = False

# Set the value to True for recipes with "Easy" keyword
df.loc[easy_recipe_indices, 'Beginner_Friendly'] = True

# %%
df['Beginner_Friendly'].value_counts(dropna=False)
# Out:
# Beginner_Friendly
# True     26742
# False    20641
# Name: count, dtype: int64

# %% [markdown]
# Create a new binary column df['Vegetarian_Friendly'] that takes the value True if the value in df['NewRecipeCategory'] indicates Vegetarian Dishes

# %%
# Define the list of non-vegetarian keywords
non_veg_keywords = {
    'meat', 'chicken', 'beef', 'pork', 'fish', 'bacon', 'ham', 
    'sausage', 'lamb', 'duck', 'goose', 'lobster', 'shrimp', 'crab', 
    'squid', 'octopus', 'calamari', 'oyster', 'mussel', 'clam', 'snail', 
    'foie gras', 'prosciutto', 'salami', 'pepperoni', 'pancetta', 
    'chorizo', 'andouille', 'boudin noir', 'blood sausage', 'pate', 
    'terrine', 'confit', 'charcuterie', 'shellfish', 'crustacean', 'mollusk', 
    'veal', 'venison', 'game', 'poultry', 'seafood', 
    'turkey', 'bison', 'elk', 'reindeer', 'wild boar', 
    'jerky', 'biltong', 
    'tuna', 'salmon', 'cod', 'haddock', 'halibut', 
    'tilapia', 'shrimp', 'prawns', 'scallops', 'mussels', 
    'clams', 'oysters', 'scallops', 'anchovies'
}

def is_non_veg(ingredient_list):
    """
    Checks if any non-vegetarian keyword is present in the list of ingredients.

    Args:
        ingredient_list: A list of ingredients.

    Returns:
        True if any non-vegetarian keyword is found, False otherwise.
    """
    for ingredient in ingredient_list:
        if any(keyword in str(ingredient).lower() for keyword in non_veg_keywords):
            return True
    return False


df['ingredients_list'] = df['ingredients'].tolist()

df['Vegetarian_Friendly'] = ~df['ingredients_list'].apply(lambda x: is_non_veg(x))

# %%
df['Vegetarian_Friendly'].value_counts(dropna=False)
# Out:
# Vegetarian_Friendly
# True     29253
# False    18130
# Name: count, dtype: int64

# %%
selected_df = df[['title','Vegetarian_Friendly', 'ingredients']][:100]

# Convert to CSV
#selected_df.to_csv('output.csv', index=False)

# %% [markdown]
# Create a new column to propose World Cuisine !
